# %% [markdown]
# # 02 — EDA / Behavioral analysis
#
# โหลด `data/integrated/labeled_dataset.parquet` แล้วสำรวจ regime และ return

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..').resolve()
p = ROOT / 'data' / 'integrated' / 'labeled_dataset.parquet'
df = pd.read_parquet(p) if p.exists() else pd.DataFrame()
print(df.shape)
