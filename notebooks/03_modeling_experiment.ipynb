# %% [markdown]
# # 03 — Modeling experiments
#
# ทดลองปรับ hyperparameter / feature เพิ่มเติม

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..').resolve()
m = ROOT / 'reports' / 'model_results.csv'
print(m.exists())
