# %% [markdown]
# # 01 — Data Check
#
# ตรวจสอบไฟล์หลังรัน pipeline ใน `data/raw/` และ `data/integrated/`

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..').resolve()
yahoo = ROOT / 'data' / 'raw' / 'yahoo'
print('Yahoo CSV count:', len(list(yahoo.glob('*.csv'))))
